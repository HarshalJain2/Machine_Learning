# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels
import statsmodels.api as sm
from warnings import filterwarnings
filterwarnings('ignore')

# %%
df1=pd.read_csv('Life_Expectancy.csv')
df1.head()
# Out:
#        Country      Status  Adult_Mortality  Infant_Deaths  Hepatitis   \
# 0  Afghanistan  Developing              263             62          65
# 1      Albania  Developing                8              0          98
# 2      Algeria  Developing               19             21          95
# 3       Angola  Developing              335             66          64
# 4    Argentina  Developing              116              8          94
#
#    Measles    BMI   Underfive_Deaths   Polio  Diphtheria    HIV           GDP  \
# 0      1154   19.1                 83      6           65   0.1    584.259210
# 1         0   57.2                  1     98           98   0.1   4575.763787
# 2        63   59.5                 24     95           95   0.1   4132.762920
# 3       118   23.3                 98      7           64   1.9   3695.793748
# 4         0   62.8                  9     93           94   0.1  13467.123600
#
# ...

# %%
X = df1.iloc[: , [3,7,8]]
X=sm.add_constant(X)
y=df1.Expected
MLR_model=sm.OLS(y,X).fit()
MLR_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:               Expected   R-squared:                       0.195
# Model:                            OLS   Adj. R-squared:                  0.175
# Method:                 Least Squares   F-statistic:                     9.690
# Date:                Sun, 16 Apr 2023   Prob (F-statistic):           8.92e-06
# Time:                        14:53:39   Log-Likelihood:                -426.90
# No. Observations:                 124   AIC:                             861.8
# Df Residuals:                     120   BIC:                             873.1
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# ...

# %%
X = df1.iloc[: , [3,7,8]]
X = sm.add_constant(X)

y = df1['Expected']

MLR_model = sm.OLS(y , X).fit()

print(MLR_model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:               Expected   R-squared:                       0.195
# Model:                            OLS   Adj. R-squared:                  0.175
# Method:                 Least Squares   F-statistic:                     9.690
# Date:                Sun, 16 Apr 2023   Prob (F-statistic):           8.92e-06
# Time:                        14:53:39   Log-Likelihood:                -426.90
# No. Observations:                 124   AIC:                             861.8
# Df Residuals:                     120   BIC:                             873.1
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# const                63.5086      3.031     20.955      0.000      57.508      69.509
# ...

# %%
X=df1.iloc[:,1:16]
encoded_status = pd.get_dummies(data = df1['Status'], drop_first=True, prefix = 'Status')
X = pd.concat([pd.DataFrame(X), encoded_status], axis=1)
X=sm.add_constant(X)
y=df1['Expected']
MLR_model_full = sm.OLS(y,X).fit()
print(MLR_model_full.f_pvalue)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_16436\1796142108.py in <module>
#       4 X=sm.add_constant(X)
#       5 y=df1['Expected']
# ----> 6 MLR_model_full = sm.OLS(y,X).fit()
#       7 print(MLR_model_full.f_pvalue)
#
# ~\anaconda3\lib\site-packages\statsmodels\regression\linear_model.py in __init__(self, endog, exog, missing, hasconst, **kwargs)
#     888                    "An exception will be raised in the next version.")
#     889             warnings.warn(msg, ValueWarning)
# --> 890         super(OLS, self).__init__(endog, exog, missing=missing,
#     891                                   hasconst=hasconst, **kwargs)
#     892         if "weights" in self._init_keys:
#
# ~\anaconda3\lib\site-packages\statsmodels\regression\linear_model.py in __init__(self, endog, exog, weights, missing, hasconst, **kwargs)
#     715         else:
# ...

# %%
X=df1.Income_Index
X=sm.add_constant(X)
y=df1.Expected
SLR_model=sm.OLS(y,X).fit()
residual=SLR_model.resid
sum_residual= np.sum(residual)
expected_error=round(np.mean(residual),13) # residual error and Expected error value

# %%
X = df1.iloc[: , [3,7,8]]
X = sm.add_constant(X)

y = df1['Expected']

# %%
# X=df1.iloc[:,1:16]
# enc_sta=pd.get_dummies(data=df1['Status'],drop_first=True,prefix='status')
# X=pd.concat([X,enc_sta],axis=1)
# X=sm.add_constant(X)
# y=df1.Expected
# MLR_model=sm.OLS(y,X).fit()

# %%
X=df1.iloc[:,1:16]
encoded_status=pd.get_dummies(data=df1['Status'],drop_first=True,prefix='Status')
X=pd.concat([X,encoded_status],axis=1)
X=sm.add_constant(X)
y=df1['Expected']

# %%
X = df1.iloc[:,1:16]
encoded_status = pd.get_dummies(data = df1['Status'], drop_first=True, prefix = 'Status')
X = pd.concat([pd.DataFrame(X), encoded_status], axis=1)
X =  sm.add_constant(X)
y = df1['Expected']
MLR_model_full = sm.OLS(y,X).fit()

# shapiro() returns a tuple having the values of test statistics and the corresponding p-value
stat, p_value = shapiro(MLR_model_full.resid)
print('Test statistic:', stat)
print('P-Value:', p_value)

# %%
X['Status_Developing'].astype(float)
